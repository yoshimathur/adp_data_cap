# %%
from preprocess.loader import DATA

# %%
DATA
# Out:
#        EmployeeID  Age Gender Department  Tenure  BenefitID  UsageFrequency  \
# 0               1   62   Male         IT       8          9               5
# 1               1   62   Male         IT       8         17               3
# 2               1   62   Male         IT       8         16               5
# 3               1   62   Male         IT       8         13               0
# 4               1   62   Male         IT       8         26               0
# ...           ...  ...    ...        ...     ...        ...             ...
# 50931        5000   63   Male      Sales      32         14               7
# 50932        5000   63   Male      Sales      32          5               3
# 50933        5000   63   Male      Sales      32         29               0
# 50934        5000   63   Male      Sales      32         26               5
# 50935        5000   63   Male      Sales      32          2               5
#
# ...

# %%
DATA.isnull().sum()
# Out:
# EmployeeID               0
# Age                      0
# Gender                   0
# Department               0
# Tenure                   0
# BenefitID                0
# UsageFrequency           0
# LastUsedDate             0
# BenefitType              0
# BenefitSubType           0
# BenefitCost              0
# SatisfactionScore    41104
# Comments             41104
# dtype: int64
